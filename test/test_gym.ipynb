# %%
import numpy as np
import gym
from hypo_gym.base import ChestSearchEnv
import matplotlib.pyplot as plt

# %%
c = ChestSearchEnv()

# %%
obs = c.reset()

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')

# %%
# action_r = 1
# action_theta = np.pi/4
# action_yaw = np.pi/2

for i in range(10):
    action = np.random.rand(3) * 2 - 1
    after_obs, reward, done, info = c.step_with_debug(action)
# Out:
# now: (-3.117723598739653, 1.1469450837170476, -0.14199188820755745),
# to (-1.2847209821327552, 1.068943835093151, 0.35996261099193116)
# start: (97, 139, -0.14199188820755745), goal: (115, 139, 0.35996261099193116)
# now: (-1.3, 1.1, 0.35996261099193116),
# to (-0.6844853442812688, -1.3332682041162913, 1.2730364547283664)
# start: (115, 139, 0.35996261099193116), goal: (121, 115, 1.2730364547283664)
# now: (-0.7000000000000001, -1.3, 1.2730364547283664),
# to (-2.243780544091009, -1.981747450531724, 1.1008450735022013)
# start: (121, 115, 1.2730364547283664), goal: (106, 108, 1.1008450735022013)
# now: (-0.7000000000000001, -1.3, 1.1008450735022013),
# to (-0.1431573173413867, -3.0827701200103506, 2.027011104436152)
# start: (121, 115, 1.1008450735022013), goal: (127, 97, 2.027011104436152)
# now: (-0.1, -3.1, 2.027011104436152),
# to (-0.3367826919630671, -2.733028580348757, 2.543327407830053)
# start: (127, 97, 2.027011104436152), goal: (125, 101, 2.543327407830053)
# now: (-0.30000000000000004, -2.7, 2.543327407830053),
# to (-1.6320709694490805, -0.5856102110251493, 2.4919912463007554)
# start: (125, 101, 2.543327407830053), goal: (112, 122, 2.4919912463007554)
# now: (-1.6, -0.6000000000000001, 2.4919912463007554),
# to (-0.24647876972410332, -0.09605668480584728, 3.133985602375663)
# start: (112, 122, 2.4919912463007554), goal: (126, 127, 3.133985602375663)
# now: (-0.2, -0.1, 3.133985602375663),
# to (0.36429748384997157, 1.65487450434997, 3.0257599955328978)
# start: (126, 127, 3.133985602375663), goal: (132, 145, 3.0257599955328978)
# now: (0.4, 1.7000000000000002, 3.0257599955328978),
# to (-0.6745019603735743, 1.4752148762166026, 2.0242525339159547)
# start: (132, 145, 3.0257599955328978), goal: (121, 143, 2.0242525339159547)
# now: (0.4, 1.7000000000000002, 2.0242525339159547),
# to (-0.27692451337186585, 3.515266919756696, -2.9035926499176394)
# start: (132, 145, 2.0242525339159547), goal: (125, 163, -2.9035926499176394)

# %%
after_obs[after_obs==-1] = 50
plt.imshow(after_obs, cmap='gray')
