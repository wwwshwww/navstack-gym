# %%
import numpy as np
import gym
from hypo_gym.base import ChestSearchEnv
import matplotlib.pyplot as plt

# %%
c = ChestSearchEnv()

# %%
obs = c.reset()

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')

# %%
# action_r = 1
# action_theta = np.pi/4
# action_yaw = np.pi/2

for i in range(10):
    action = np.random.rand(3) * 2 - 1
    after_obs, reward, done, info = c.step_with_debug(action)
# Out:
# now: (-1.5969823572990642, -1.9833492211778485, 2.361687717282846),
# to (0.8267709011065647, -2.5735279135047806, -3.04706979854097)
# start: (112, 108, 2.361687717282846), goal: (136, 102, -3.04706979854097)
# now: (0.8, -2.6, -3.04706979854097),
# to (0.8373869716381004, -2.589324808703991, 1.8219280133823226)
# start: (136, 102, -3.04706979854097), goal: (136, 102, 1.8219280133823226)
# now: (0.8, -2.6, 1.8219280133823226),
# to (1.0216347617246275, -3.901071242937566, 2.145934437948239)
# start: (136, 102, 1.8219280133823226), goal: (138, 89, 2.145934437948239)
# now: (1.0, -3.9000000000000004, 2.145934437948239),
# to (2.158781487251999, -5.631942461136374, 2.3426233480395204)
# start: (138, 89, 2.145934437948239), goal: (150, 72, 2.3426233480395204)
# now: (1.0, -3.9000000000000004, 2.3426233480395204),
# to (1.1625418979550965, -1.8912616549261925, 1.4111159108114366)
# start: (138, 89, 2.3426233480395204), goal: (140, 109, 1.4111159108114366)
# ...

# %%
after_obs[after_obs==-1] = 50
plt.imshow(after_obs, cmap='gray')
