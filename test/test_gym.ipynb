# %%
import numpy as np
import gym
from hypo_gym.base import ChestSearchEnv
import matplotlib.pyplot as plt

# %%
env = ChestSearchEnv()

# %%
obs = env.reset()

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')

# %%
for i in range(10):
    action = env.action_space.sample()
    print(f'==========\naction: {action}')
    obs, reward, done, info = env.step_with_debug(action)
# Out:
# ==========
# action: [-0.158089   -0.18102401 -0.19230077]
# now: (-1.8638295095662074, 2.233761988515983, 1.4503379948847193),
# to (-2.023221381740813, 1.8617637887365721, 1.1482726569023587)
# start: (109, 150, 1.4503379948847193), goal: (108, 147, 1.1482726569023587)
# ==========
# action: [ 0.42364624  0.95905584 -0.6348413 ]
# now: (-1.8638295095662074, 2.233761988515983, 1.4503379948847193),
# to (-2.929902869905715, 2.4330166184510085, 0.45313157677756966)
# start: (109, 150, 1.4503379948847193), goal: (99, 152, 0.45313157677756966)
# ==========
# action: [-0.5990473  -0.47124806 -0.58224523]
# now: (-2.9000000000000004, 2.4000000000000004, 0.45313157677756966),
# to (-4.370789704094197, 2.8342663722674053, -0.4614570928601651)
# start: (99, 152, 0.45313157677756966), goal: (84, 156, -0.4614570928601651)
# ==========
# action: [-0.7815946  -0.1161281  -0.74813485]
# now: (-2.9000000000000004, 2.4000000000000004, -0.4614570928601651),
# to (-4.500261887513108, 3.601120773225949, -1.6366245694740063)
# start: (99, 152, -0.4614570928601651), goal: (83, 164, -1.6366245694740063)
# ==========
# action: [-0.2564899   0.5250887  -0.76285136]
# now: (-2.9000000000000004, 2.4000000000000004, -1.6366245694740063),
# to (-3.351869497903658, 2.876399097563198, -2.8349086796627097)
# start: (99, 152, -1.6366245694740063), goal: (94, 157, -2.8349086796627097)
# ==========
# action: [-0.2977715  -0.83191335 -0.9712301 ]
# now: (-3.4000000000000004, 2.9000000000000004, -2.8349086796627097),
# to (-2.9881831111419754, 2.2585168508825184, 1.922671970199266)
# start: (94, 157, -2.8349086796627097), goal: (98, 151, 1.922671970199266)
# ==========
# action: [ 0.365979    0.64713275 -0.740963  ]
# now: (-3.0, 2.3000000000000003, 1.922671970199266),
# to (-3.917779785196844, 2.488344103695259, 0.7587700395034886)
# start: (98, 151, 1.922671970199266), goal: (89, 153, 0.7587700395034886)
# ==========
# action: [ 0.9797129   0.48052314 -0.1498891 ]
# now: (-3.9000000000000004, 2.5, 0.7587700395034886),
# to (-3.756561046278911, 5.003959958966387, 0.5233247971098023)
# start: (89, 153, 0.7587700395034886), goal: (90, 178, 0.5233247971098023)
# ==========
# action: [-0.01849982 -0.6031479  -0.77401423]
# now: (-3.9000000000000004, 2.5, 0.5233247971098023),
# to (-3.943163978943348, 2.519488386809193, -0.692493919397065)
# start: (89, 153, 0.5233247971098023), goal: (89, 153, -0.692493919397065)
# ==========
# action: [ 0.8478236   0.12082812 -0.56896955]
# now: (-3.9000000000000004, 2.5, -0.692493919397065),
# to (-1.9980837112495573, 1.4543068518595061, -1.5862291950586656)
# start: (89, 153, -0.692493919397065), goal: (108, 143, -1.5862291950586656)

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')
