# %%
import numpy as np
import gym
from hypo_gym.base import ChestSearchEnv
import matplotlib.pyplot as plt

# %%
env = ChestSearchEnv(path_turnable=np.pi/8, avoidance_size=3, move_limit=-1, path_planning_count=10, path_exploration_count=4000)

# %%
obs = env.reset()

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')

# %%
for i in range(100):
    action = env.action_space.sample()
    print(f'==========\naction: {action}')
    obs, reward, done, info = env.step(action)
# Out:
# ==========
# action: [ 0.81654334 -0.05064209 -0.10034359]
# ==========
# action: [-0.10019252  0.6252433   0.6142376 ]
# ==========
# action: [-0.5234483  -0.40456587 -0.6197573 ]
# ==========
# action: [-0.53812873  0.7659167   0.32402074]
# ==========
# action: [-0.2778747 -0.2464397  0.5265468]
# ==========
# action: [ 0.9620806  -0.86808604 -0.62563   ]
# ==========
# action: [-0.14430909  0.90196776 -0.21620333]
# ==========
# action: [ 0.9265644   0.750147   -0.48138598]
# ==========
# action: [-0.19576745 -0.51693726 -0.5444316 ]
# ==========
# action: [-0.5245046  -0.46323353  0.00341915]
# ==========
# action: [ 0.82361245 -0.6277349   0.56614554]
# ==========
# action: [-0.5172858  -0.75712585  0.45640913]
# ==========
# action: [ 0.4693037  -0.8111925   0.02169759]
# ==========
# action: [ 0.4777842 -0.5420583  0.4688487]
# ==========
# action: [0.640365  0.7913705 0.6177218]
# ==========
# action: [ 0.70791364 -0.16934259 -0.6981208 ]
# ==========
# action: [ 0.97785515 -0.6124959   0.9352042 ]
# ==========
# action: [-0.75419396  0.08392297  0.45238763]
# ==========
# action: [-0.63881993  0.34748024  0.8041592 ]
# ==========
# action: [-0.37060106 -0.9974447  -0.65197825]
# ==========
# action: [-0.748959   -0.9497542  -0.84083515]
# ==========
# action: [-0.7817     -0.79639345  0.27363104]
# ==========
# action: [-0.34367168  0.27033472  0.63662356]
# ==========
# action: [ 0.46511853 -0.6987699  -0.9272815 ]
# ==========
# action: [ 0.85438526 -0.9933625  -0.28747553]
# ==========
# action: [-0.33777386 -0.90576226  0.6697392 ]
# ==========
# action: [-0.02589024 -0.8503203  -0.09736823]
# ==========
# action: [-0.5053906  -0.56102836  0.9112688 ]
# ==========
# action: [ 0.09051646 -0.00775812  0.30970123]
# ==========
# action: [-0.89560544 -0.48077825 -0.3224165 ]
# ==========
# action: [-0.91897905  0.7323883  -0.83454263]
# ==========
# action: [-0.93613994 -0.63166493 -0.3090307 ]
# ==========
# action: [ 0.03004127 -0.40282607  0.6605082 ]
# ==========
# action: [-0.2742665   0.7941108  -0.07910542]
# ==========
# action: [ 0.01420175 -0.4166745   0.38272956]
# ==========
# action: [ 0.5483295  -0.6562151   0.19226529]
# ==========
# action: [-0.39964396  0.4170744   0.84929866]
# ==========
# action: [-0.42027417  0.06478436  0.5434352 ]
# ==========
# action: [ 0.12178264 -0.6383238  -0.3380703 ]
# ==========
# action: [-0.46367994 -0.7903668   0.04273827]
# ==========
# action: [-0.08086912  0.62601376 -0.09695055]
# ==========
# action: [0.25994307 0.01209388 0.3453371 ]
# ==========
# action: [-0.83606917 -0.9481588  -0.15059197]
# ==========
# action: [-0.11488595 -0.887055   -0.40808353]
# ==========
# action: [-0.98976797  0.23602757  0.580453  ]
# ==========
# action: [0.14981489 0.6052558  0.62128407]
# ==========
# action: [ 0.16334972 -0.9769969  -0.5796496 ]
# ==========
# action: [-0.4572361   0.61121386 -0.4564262 ]
# ==========
# action: [ 0.3644101   0.87759876 -0.49232504]
# ==========
# action: [ 0.30473784 -0.34235469  0.2545814 ]
# ==========
# action: [-0.5816238   0.12506494 -0.15731493]
# ==========
# action: [ 0.73205173 -0.02275464 -0.6513343 ]
# ==========
# action: [-0.87726253 -0.323894   -0.7826879 ]
# ==========
# action: [-0.19485304  0.9778342  -0.48242027]
# ==========
# action: [-0.73636013 -0.62312603  0.1596658 ]
# ==========
# action: [-0.90651476 -0.2742007  -0.62909424]
# ==========
# action: [ 0.91324043 -0.13529591  0.5044473 ]
# ==========
# action: [-0.08509005 -0.03107798 -0.99336994]
# ==========
# action: [0.45588952 0.68714875 0.5629553 ]
# ==========
# action: [-0.5487557  -0.58925754 -0.20646836]
# ==========
# action: [0.1634496 0.4466821 0.6661224]
# ==========
# action: [0.03820935 0.52214557 0.7593439 ]
# ==========
# action: [ 0.2775714  0.4890451 -0.9510254]
# ==========
# action: [-0.37686387 -0.5853513  -0.65750724]
# ==========
# action: [-0.5437303  -0.40959483 -0.33278   ]
# ==========
# action: [ 0.08325368 -0.75658727 -0.77345854]
# ==========
# action: [ 0.22957844 -0.73299605  0.73119986]
# ==========
# action: [ 0.04182213  0.44033033 -0.589563  ]
# ==========
# action: [ 0.19370301 -0.8451229  -0.49112016]
# ==========
# action: [ 0.4824882  -0.33988693  0.16688022]
# ==========
# action: [ 0.9874793  -0.7931129  -0.95411766]
# ==========
# action: [ 0.6921177   0.43896946 -0.44395062]
# ==========
# action: [ 0.8042145  -0.07146972 -0.22471386]
# ==========
# action: [-0.880145   -0.9537119  -0.17754741]
# ==========
# action: [-0.53494143  0.16181433 -0.10839367]
# ==========
# action: [ 0.5385483  -0.20143718  0.3729843 ]
# ==========
# action: [ 0.53176993  0.63028926 -0.1902614 ]
# ==========
# action: [-0.01565229 -0.960436    0.26373643]
# ==========
# action: [0.78637034 0.01506303 0.15142652]
# ==========
# action: [-0.49464846  0.9320869   0.10563089]
# ==========
# action: [ 0.8294151   0.43532044 -0.6753868 ]
# ==========
# action: [ 0.20058891 -0.6894102  -0.6664392 ]
# ==========
# action: [-0.95235604 -0.2251058  -0.5365459 ]
# ==========
# action: [ 0.37944874 -0.48029706 -0.02553313]
# ==========
# action: [0.05469787 0.09953809 0.01864901]
# ==========
# action: [0.1149909  0.8110048  0.46166924]
# ==========
# action: [ 0.45484653  0.3594737  -0.16937965]
# ==========
# action: [ 0.7073747   0.98833245 -0.27379972]
# ==========
# action: [ 0.4060238   0.10543845 -0.77464277]
# ==========
# action: [-0.6483546   0.01061116 -0.9171933 ]
# ==========
# action: [ 0.18379435 -0.47159606 -0.02743559]
# ==========
# action: [-0.26347995 -0.7953431   0.09968974]
# ==========
# action: [ 0.2169255 -0.6533769  0.5522729]
# ==========
# action: [ 0.06525885 -0.8281606   0.1665127 ]
# ==========
# action: [ 0.76146466 -0.23636013 -0.55535334]
# ==========
# action: [-0.15260234 -0.32672384 -0.22993127]
# ==========
# action: [-0.08404364 -0.02586106  0.28352246]
# ==========
# action: [-0.0982083  -0.08454725 -0.42143923]
# ==========
# action: [0.3497144  0.37273148 0.36348236]
# ==========
# action: [ 0.6362296   0.49160692 -0.39010295]
