# %%
import numpy as np
import gym
from hypo_gym.base import ChestSearchEnv
import matplotlib.pyplot as plt

# %%
env = ChestSearchEnv()

# %%
obs = env.reset()

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')

# %%
for i in range(10):
    action = env.action_space.sample()
    print(f'==========\naction: {action}')
    obs, reward, done, info = env.step_with_debug(action)
# Out:
# ==========
# action: [ 0.10045333 -0.7509904   0.8264037 ]
# now: (-0.8182508761092011, 2.2922224824026336, -2.3363078724153565),
# to: (-1.0576001746081014, 2.3862621099243593, -1.038196011405847)
# Navigation started: (120, 151, -2.3363078724153565) to (117, 152, -1.038196011405847)
# ==========
# action: [ 0.16217425  0.43358362 -0.8778241 ]
# now: (-1.1, 2.4000000000000004, -1.038196011405847),
# to: (-0.7110284256134645, 2.254865585754068, -2.417078926728262)
# Navigation started: (117, 152, -1.038196011405847) to (121, 151, -2.417078926728262)
# ==========
# action: [-0.42241105 -0.66388106  0.22508991]
# now: (-0.7000000000000001, 2.3000000000000003, -2.417078926728262),
# to: (0.32705090292541417, 1.9615735053738617, -2.0635085265990414)
# Navigation started: (121, 151, -2.417078926728262) to (131, 148, -2.0635085265990414)
# ==========
# action: [0.278233   0.00672076 0.5492422 ]
# now: (-0.7000000000000001, 2.3000000000000003, -2.0635085265990414),
# to: (-1.0302753326381644, 1.6689247601701693, -1.2007608987259242)
# Navigation started: (121, 151, -2.0635085265990414) to (118, 145, -1.2007608987259242)
# ==========
# action: [-0.19433805 -0.04418275 -0.04727663]
# now: (-0.7000000000000001, 2.3000000000000003, -1.2007608987259242),
# to: (-0.8473238866042023, 2.775191868881341, -1.2750228570402828)
# Navigation started: (121, 151, -1.2007608987259242) to (120, 156, -1.2750228570402828)
# ==========
# action: [-0.31946996 -0.40938324 -0.7358592 ]
# now: (-0.7000000000000001, 2.3000000000000003, -1.2007608987259242),
# to: (-0.4794743527619677, 3.0875504841624357, -2.3566458510938038)
# Navigation started: (121, 151, -1.2007608987259242) to (123, 159, -2.3566458510938038)
# ==========
# action: [-0.99946916 -0.6739058   0.3431264 ]
# now: (-0.7000000000000001, 2.3000000000000003, -2.3566458510938038),
# to: (1.7634557479448185, 1.6086029996039668, -1.8176641837039353)
# Navigation started: (121, 151, -2.3566458510938038) to (146, 144, -1.8176641837039353)
# ==========
# action: [-0.63093865 -0.02398507  0.12497789]
# now: (1.8, 1.6, -1.8176641837039353),
# to: (2.25341871772671, 3.150255466018364, -1.6213493783814474)
# Navigation started: (146, 144, -1.8176641837039353) to (151, 160, -1.6213493783814474)
# ==========
# action: [ 0.45269194 -0.41206372  0.17860664]
# now: (2.3000000000000003, 3.2, -1.6213493783814474),
# to: (1.5553546484055543, 2.3120064673532488, -1.3407947176165638)
# Navigation started: (151, 160, -1.6213493783814474) to (144, 151, -1.3407947176165638)
# ==========
# action: [-0.3456993   0.46747273  0.71776885]
# now: (1.6, 2.3000000000000003, -1.3407947176165638),
# to: (0.8728446082019988, 2.804433098753653, -0.21332604778091202)
# Navigation started: (144, 151, -1.3407947176165638) to (137, 156, -0.21332604778091202)

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')
