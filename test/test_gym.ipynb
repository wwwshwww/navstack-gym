# %%
import numpy as np
import gym
from hypo_gym.base import ChestSearchEnv
import matplotlib.pyplot as plt

# %%
env = ChestSearchEnv(move_limit=-1, path_exploration_count=25000, path_planning_count=15)

# %%
obs = env.reset()

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')

# %%
for i in range(10):
    action = env.action_space.sample()
    print(f'==========\naction: {action}')
    obs, reward, done, info = env.step_with_debug(action)
# Out:
# ==========
# action: [-0.24424063 -0.0452551  -0.48080224]
# now: (-1.9798478343488135, -2.4393285693488362, 1.3998885550783888),
# to: (-2.129683749018162, -3.0463658578495414, 0.6446461657328295)
# Navigation started: (108, 104, 1.3998885550783888) to (107, 98, 0.6446461657328295)
# ==========
# action: [-0.03320739  0.22063643 -0.73221934]
# now: (-2.1, -3.0, 0.6446461657328295),
# to: (-2.146557818034875, -3.071128247887742, -0.505521281460867)
# Navigation started: (107, 98, 0.6446461657328295) to (107, 97, -0.505521281460867)
# ==========
# action: [-0.6501164   0.15420863  0.00912355]
# now: (-2.1, -3.1, -0.505521281460867),
# to: (-3.706944092539694, -2.666850687511362, -0.4911900371013007)
# Navigation started: (107, 97, -0.505521281460867) to (91, 101, -0.4911900371013007)
# ==========
# action: [0.8801989  0.41812024 0.11119052]
# now: (-3.7, -2.7, -0.4911900371013007),
# to: (-1.4775138520555666, -2.3285736224325837, -0.31653237635438547)
# Navigation started: (91, 101, -0.4911900371013007) to (113, 105, -0.31653237635438547)
# ==========
# action: [ 0.6878559 -0.6167815  0.5428915]
# now: (-1.5, -2.3000000000000003, -0.31653237635438547),
# to: (-1.004187085269929, -3.9896678560511205, 0.5362396014328645)
# Navigation started: (113, 105, -0.31653237635438547) to (118, 88, 0.5362396014328645)
# ==========
# action: [-0.86669624 -0.67581147 -0.2957354 ]
# now: (-1.0, -4.0, 0.5362396014328645),
# to: (-2.9195720728511096, -2.887318210695408, 0.07169953869748857)
# Navigation started: (118, 88, 0.5362396014328645) to (99, 99, 0.07169953869748857)
# ==========
# action: [ 0.7848156   0.5847579  -0.93433905]
# now: (-1.0, -4.0, 0.07169953869748857),
# to: (0.10199315271992093, -2.320057664133609, -1.3959568034916263)
# Navigation started: (118, 88, 0.07169953869748857) to (129, 105, -1.3959568034916263)
# ==========
# action: [-0.90443504 -0.7864225  -0.7192634 ]
# now: (0.1, -2.3000000000000003, -1.3959568034916263),
# to: (2.1203433099130486, -1.1690377281648843, -2.525773070634129)
# Navigation started: (129, 105, -1.3959568034916263) to (149, 116, -2.525773070634129)
# ==========
# action: [-0.2090561  -0.17650075  0.38036197]
# now: (2.1, -1.2000000000000002, -2.525773070634129),
# to: (2.6048010365585452, -1.022243422977272, -1.9283018786465038)
# Navigation started: (149, 116, -2.525773070634129) to (154, 118, -1.9283018786465038)
# ==========
# action: [-0.29597962 -0.6020741  -0.5905482 ]
# now: (2.6, -1.0, -1.9283018786465038),
# to: (3.330748709424408, -0.7996815752437544, -2.855932849171278)
# Navigation started: (154, 118, -1.9283018786465038) to (161, 120, -2.855932849171278)

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')
