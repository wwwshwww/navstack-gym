# %%
import numpy as np
import gym
from hypo_gym.base import ChestSearchEnv
import matplotlib.pyplot as plt

# %%
c = ChestSearchEnv()

# %%
obs = c.reset()

# %%
obs[obs==-1] = 50
plt.imshow(obs, cmap='gray')

# %%
action_r = 1
action_theta = np.pi/4
action_yaw = np.pi/2

# after_obs, reward, done, info = c.step_debug([action_r, action_theta, action_yaw])
after_obs, reward, done, info = c.step([action_r, action_theta, action_yaw])
# Out:
# start: (128, 128, 0), goal: (135, 135, 1.5707963267948966)

# %%
after_obs[after_obs==-1] = 50
plt.imshow(after_obs, cmap='gray')
